# %% [markdown]
# https://www.youtube.com/watch?v=UWMzKXsY9A4

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)
 #Membuat objek resource YouTube menggunakan googleapiclient.discovery.build,
 #dengan API versi v3. api_key adalah kunci API yang harus didefinisikan agar bisa mengakses data dari YouTube.

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()
 #Mengambil komentar utama dari video berdasarkan video_id, dengan parameter part='snippet, replies'
 #yang menentukan agar data yang diambil mencakup informasi dasar (snippet) dan balasan (replies).

	# iterate video response
	while video_response:

		# extracting required info
		# from each result object
		for item in video_response['items']:

			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt'] #Waktu komentar dipublikasikan
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName'] #Nama pengguna yang membuat komentar

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount'] #Jumlah like pada komentar

			replies.append([published, user, comment, likeCount])

			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:

					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay'] #
					likeCount = reply['snippet']['likeCount']
					#Jika komentar memiliki balasan, fungsi ini akan mengulang melalui setiap balasan

					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
# Isikan dengan API key
api_key = 'AIzaSyBDTqd8_wiVVKwy2ypp4EGBEGU8s4VZI58'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=UWMzKXsY9A4
video_id = "UWMzKXsY9A4"

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2025-04-05T06:55:04Z',
#   '@nicolas.marsicano',
#   'So as the grandma saved a lot of lives decades ago, surely the descendants of those people are the dead ones in the previous movies. At least some of them, and the others were collateral .And its all connected. SHIVERS!',
#   0],
#  ['2025-04-05T06:07:22Z',
#   '@bonnnielin',
#   'oh how i’ve been craving for a new final destination film and here we are',
#   0],
#  ['2025-04-05T05:32:27Z',
#   '@BabaDongeng',
#   'After saw FD1, i always carrefoul drive behind/near a big truck (logging truck etc).',
#   0],
#  ['2025-04-05T05:02:23Z',
#   '@TheAdministratorSCPF',
#   'I don’t care how expensive ice is if glass shatters around it you bet that I’m throwing everything away',
#   0],
#  ['2025-04-05T04:23:44Z',
#   '@sanketgavade8244',
#   'This movie make me overthink about every second..',
#   0],
#  ['2025-04-05T04:23:39Z',
#   '@lolyscandy9157',
#   'baru trailer aja udah astaghfirullah astaghfirullah',
#   0],
#  ['2025-04-05T03:58:34Z',
#   '@Tokyobgm68',
#   'Final Destination taught me to fear roller coasters, tanning beds, highways, airplanes, and basically existing.',
#   0],
#  ['2025-04-05T03:53:50Z',
#   '@Odysseus38',
#   'Great new reasons to not do things in life 😂😂😂',
#   0],
#  ['2025-04-05T03:07:28Z', '@VidhiVij', 'Finally decades wait is over...', 0],
#  ['2025-04-05T01:18:32Z', '@briajali', 'Tonyyyy Toddddddd😢😫😔❤️❤️', 0],
#  ['2025-04-05T01:09:19Z', '@Cantabispo', 'Ih historinha? Sei não heim', 0],
#  ['2025-04-05T01:07:03Z',
#   '@Blackheart0006',
#   '“But death doesn’t like it when you mess with its plans”',
#   0],
#  ['2025-04-05T00:58:31Z',
#   '@GigiGame-g7e',
#   'People miss this MOVIE! This will be popular horror movie again👏👏',
#   2],
#  ['2025-04-04T23:33:12Z',
#   '@seand2486',
#   'I can&#39;t listen to rollercoaster of love without the tanning bed scene assaulting my brain like why?! I don&#39;t even use them?! 😂',
#   1],
#  ['2025-04-04T22:57:23Z', '@KabyJackson', 'Here we go again🙏😭🤷🏿\u200d♂️', 0],
#  ['2025-04-04T22:57:23Z',
#   '@willbrown6298',
#   'Wait, wasn&#39;t one of the only established weaknesses was having children? The list is suppose to be invalidated if one of the survivors has a child.',
#   2],
#  ['2025-04-04T22:19:18Z',
#   '@FriendGood-n2p',
#   'You traded gold for Ashe&#39;s the best thing you ever did flesh of my flesh check mate your move',
#   0],
#  ['2025-04-04T22:11:51Z', '@FriendGood-n2p', 'I win God&#39;s', 0],
#  ['2025-04-04T21:25:12Z',
#   '@mounirmugen3900',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=125">2:05</a> I predict this is grandma death here',
#   1],
#  ['2025-04-04T20:42:14Z',
#   '@muhammadarbee270',
#   'Now we have to check the ice before we drink it.....<br>Damn it',
#   0],
#  ['2025-04-04T20:36:28Z',
#   '@zyongslife',
#   'I wonder how  they will try and connect this movie with the previous movies. This could be good!',
#   0],
#  ['2025-04-04T20:28:38Z',
#   '@alexjq1992',
#   'Nah. This is too soon. I still have recovered from my childhood trauma from like 15 years ago',
#   1],
#  ['2025-04-04T19:51:27Z',
#   '@Triggermangravy',
#   'Ooohhhhh man I didn&#39;t see that one coming wtf',
#   0],
#  ['2025-04-04T19:33:01Z', '@user-bn2hv8nn7x', '😊', 0],
#  ['2025-04-04T19:28:42Z',
#   '@SergioPenagos-s6n',
#   'Esta va a hacer epico papus. 💀👻☠️',
#   0],
#  ['2025-04-04T19:18:44Z',
#   '@armysworld6638',
#   'Truck kun in multiverse😩... I cannot with how many trucks have been killing this people😭',
#   0],
#  ['2025-04-04T19:00:57Z',
#   '@TejasYogi',
#   'this trailer give chills from 57 sec !! amazing job to the music editor&#39;s team the music is so wonderful behind and amazing job to the camera person team as well for the insane visuals !!!! THIS IS WHAT WE CALL A GOATED DIRECTER',
#   0],
#  ['2025-04-04T18:59:02Z', '@trubenok', 'I both hate and love it! 😱', 0],
#  ['2025-04-04T18:41:07Z',
#   '@이마크-r8e',
#   'FD gave me fears I never even thought about. Glass shards on ice? Fckin genious lmao.',
#   1],
#  ['2025-04-04T18:40:30Z', '@dekis_xwz', '‼️', 0],
#  ['2025-04-04T18:20:36Z',
#   '@skabdulsajeed2984',
#   'Just a week I watched the whole final destination series again, and now this can&#39;t wait for the new movie definitely I&#39;ll going to the theater to watch this',
#   0],
#  ['2025-04-04T17:34:21Z',
#   '@movinitlikedat45',
#   '&quot;Only by embracing Death will it pass you by.&quot;<br>Yeah, I think Kimberly Corman tried that, only for Brian Gibbons to get blown-up at a barbecue.',
#   2],
#  ['2025-04-04T17:29:43Z',
#   '@movinitlikedat45',
#   'Could this tie the entire series together? What if the vics of the past 5 films were connected to/descended from not just Iris, but EVERYONE in that high-rise (at least the ones who got out of that high-rise)?',
#   0],
#  ['2025-04-04T17:01:59Z',
#   '@Su-jin47',
#   'I think in final destination water is main villain like, tod death, the teacher who death by computer and more',
#   0],
#  ['2025-04-04T16:24:11Z',
#   '@kaneheine3524',
#   'They better make more movies after this, you can make as many of these as you want and I won&#39;t get bored of it',
#   0],
#  ['2025-04-04T16:19:21Z',
#   '@alirizvi5663',
#   'Isn&#39;t this the exact opposite of the plot of Final Destination 2?',
#   0],
#  ['2025-04-04T16:05:49Z',
#   '@lakhisingh3105',
#   'Can&#39;t watch in the theatre, scary, heart Beats are increasing',
#   0],
#  ['2025-04-04T15:48:50Z', '@josuerosales5625', '🥱🥱', 0],
#  ['2025-04-04T15:25:03Z',
#   '@jonathanoxlade4252',
#   'Death wants to play a game and your it',
#   0],
#  ['2025-04-04T15:23:10Z', '@Simona0707', 'EPICCC. Can’t wait to watch it', 0],
#  ['2025-04-04T15:22:26Z',
#   '@jonathanoxlade4252',
#   'The lawnmower  strikes again',
#   0],
#  ['2025-04-04T14:58:44Z',
#   '@RSrider-ip8mw',
#   'Finally, childhood trauma is going to come back again',
#   0],
#  ['2025-04-04T14:55:47Z',
#   '@hoverschmoover',
#   'Oh my.. I’m getting goosebumps just from watching this movie trailer alone.',
#   0],
#  ['2025-04-04T14:33:12Z',
#   '@ariefsaepudin6795',
#   'Apakah masih nyambung dengan FD yg sebelum nya,?',
#   0],
#  ['2025-04-04T14:32:24Z',
#   '@DesiReactorSyndicate',
#   'Worst time to be alive. Studios keep milking the same story. No one writing a new one',
#   0],
#  ['2025-04-04T14:31:39Z',
#   '@AYITSMEee',
#   'After 14 years, The last FD5 was released in 2011 and finally the sequel is out after 14 years! 🔥🔥',
#   1],
#  ['2025-04-04T14:30:54Z', '@Havoc837', 'RIP tony todd', 3],
#  ['2025-04-04T13:25:02Z',
#   '@cuthiey4040',
#   'One sequel that&#39;ll make you afraid to do absolutely anything😂🙌',
#   0],
#  ['2025-04-04T12:00:41Z',
#   '@ELISNTREALL',
#   'they showed the guy in the teaser trailer dying by a bus??? half of these deaths have GOT to be fake 💔💔💔',
#   0],
#  ['2025-04-04T13:25:05Z',
#   '@eatmyshorts7973',
#   'The bus drove on the side of him',
#   0],
#  ['2025-04-04T11:58:29Z',
#   '@louisecalyore-ik2hb',
#   'Looks like a good move, a real thriller! Holy moly!',
#   0],
#  ['2025-04-04T11:53:12Z', '@Xylotek-cp8qp', 'Rip tony todd', 0],
#  ['2025-04-04T10:35:28Z',
#   '@anaalbaladejo7703',
#   'I will not lie, final destination taught me to be anxious and to feel that about everything.',
#   11],
#  ['2025-04-04T10:28:54Z',
#   '@rainross5525',
#   'Great, another part of life phobias',
#   3],
#  ['2025-04-04T10:28:35Z',
#   '@baffledbafel',
#   'If any movie franchise had any  positively impactful contribution to the humanity, it would be this one. All these movies actually taught us to be careful of any seemingly insignificant incidents that might lead to deadly consequences.',
#   2],
#  ['2025-04-04T09:15:34Z', '@NagiCookie', 'Can&#39;t wait ❤', 1],
#  ['2025-04-04T09:13:03Z', '@joshuabeldo2656', 'RIP Tony Todd….🔥🙏🏾❤️🙏🏾', 2],
#  ['2025-04-04T09:04:00Z', '@abhij9002', 'Mid ahhh trailer', 0],
#  ['2025-04-04T08:46:45Z',
#   '@VickeyCreation',
#   'Finally wait is over ❤ love u',
#   1],
#  ['2025-04-04T08:46:06Z',
#   '@ArthuroArthuro-o5w',
#   'Woah.. After many years I m waiting to this continuations of movies, 😱🥺🙄🤔🥹🤤🤤💦😋😘❤️😍🙏💕💋',
#   0],
#  ['2025-04-04T08:45:10Z',
#   '@devonaiello5469',
#   'Okay this trailer alone is giving such anxiety',
#   1],
#  ['2025-04-04T08:28:00Z', '@sceeney', 'now THIS is what people want.', 0],
#  ['2025-04-04T08:15:20Z',
#   '@jamesmuhuhu7987',
#   'Walking backwards onto a road is basically suicide you can&#39;t be helped',
#   0],
#  ['2025-04-04T07:32:26Z',
#   '@adityaawasthi3709',
#   'They are ready to give trauma to this generation',
#   1],
#  ['2025-04-04T07:26:03Z',
#   '@eduardoramirezesquivel4217',
#   'Now that I&#39;m starting to read the comics and soon the novels, I just realized that dad&#39;s death is very similar like the one from Final Destination: Sacrifice. <br><br>I hope, it is as gore as in the comic.<br><br>Also the movie might have missed several stuff from the novels and comics, like from Destination Zero, looks could kill, etc.<br><br>I&#39;m gonna start reading the novels and then the marathon of movies before the sixth installment.',
#   1],
#  ['2025-04-04T07:11:59Z',
#   '@DJ_Stymulus',
#   'I was totally set on going to see this at the theater BUT when the black gentlemen said &quot;only by embracing death will it pass you by&quot;...🤡🤡🤦🏾🤡🤡🤦🏾',
#   2],
#  ['2025-04-04T07:10:32Z', '@wyattwest7299', '🎉', 0],
#  ['2025-04-04T07:00:03Z',
#   '@GRiZZiNK',
#   'Rest in peace Tony Todd I&#39;m DEFINITELY checking this out on his honor alone',
#   0],
#  ['2025-04-04T06:59:39Z',
#   '@PlayingWithWilson',
#   'I&#39;m still waiting for a good movie to be made post covid and this ain&#39;t it.',
#   1],
#  ['2025-04-04T06:56:56Z',
#   '@IA_n_Ch',
#   'hello truck kun<br><br>that time i got reincarnated as a ...',
#   0],
#  ['2025-04-04T06:40:02Z',
#   '@josekamaa2616',
#   'ooooo am sooooo hyped for this right here',
#   0],
#  ['2025-04-04T05:52:00Z', '@YourHighSchoolBestie', 'wow!', 0],
#  ['2025-04-04T05:39:14Z',
#   '@Mr.Vighlme',
#   'Final Destination is Happy Tree Friends in disguise.',
#   1],
#  ['2025-04-04T05:38:52Z',
#   '@suburbansurferamvs6800',
#   'Are they going in the order of birth? Also does the in-laws count?',
#   1],
#  ['2025-04-04T13:26:14Z', '@eatmyshorts7973', 'Yes', 0],
#  ['2025-04-04T05:12:37Z',
#   '@kristincavalli9740',
#   'This is gonna be the best one yet!!!',
#   0],
#  ['2025-04-04T04:49:29Z',
#   '@nicloren2220',
#   'did anyone else look out for the hice pale ale ?',
#   0],
#  ['2025-04-04T04:37:32Z',
#   '@beingmaanav',
#   'It&#39;s a perfect time to end the series.',
#   1],
#  ['2025-04-04T04:37:07Z', '@otakuwolf4ever985', 'RIP Mr. Todd.', 0],
#  ['2025-04-04T04:04:22Z',
#   '@Bossdealingz',
#   'Dude y does this franchise love freaking ppl the f out while giving them new phobias😅 of fear 😨',
#   0],
#  ['2025-04-04T03:29:19Z', '@FractureFin', 'Yes yes yes ❤', 0],
#  ['2025-04-04T03:26:16Z',
#   '@PresidentWORLD-h3o',
#   'Mr. Warner! I&#39;S! NOT your business !!! O.K. MAGA ALOHA!<br><b>Free Luigi! FREEDOM U.S. PRESIDENT! Free Luigi! FREEDOM PEOPLE&#39;S!</b><br>East&amp;West needs PEACE Politics! NoW! MAGA!<br><b>ALOHA!</b>',
#   0],
#  ['2025-04-04T02:03:08Z', '@GabbieSo', 'Im so scared', 0],
#  ['2025-04-04T01:09:50Z',
#   '@Figueiredomath1',
#   'ISSO ESTÁ MUITO FODAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA',
#   0],
#  ['2025-04-04T00:48:49Z', '@tobi_uzamaki34', 'Real', 0],
#  ['2025-04-04T00:42:34Z',
#   '@gimmefriespls',
#   'Me after seeing <a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=13">0:13</a> - <a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=15">0:15</a> : &quot;oh no..... 😰😰😰&quot;',
#   0],
#  ['2025-04-04T00:31:13Z',
#   '@ColleenaBrown-b7b',
#   'Can’t wait to see this. Love these movies ❤',
#   0],
#  ['2025-04-03T23:54:32Z', '@rhaylaynne7138', '🎉🎉🎉', 0],
#  ['2025-04-03T23:49:45Z', '@myboys313', 'FINAL DESTINATION RAISED ME! 😂😂😂', 0],
#  ['2025-04-03T23:45:06Z',
#   '@zahir2025-c9w',
#   'Watching Final Destination since my childhood.<br>Waiting for this latest version of it.',
#   0],
#  ['2025-04-03T23:42:50Z',
#   '@aravindvenu1560',
#   'Watching it in IMAX would be insane!',
#   0],
#  ['2025-04-03T23:33:42Z',
#   '@TrendMixBox',
#   'I Think This Movie Can Be Very Good🎉',
#   0],
#  ['2025-04-03T22:39:48Z', '@agustinabecerra1118', '🙌🏽😍', 0],
#  ['2025-04-03T22:39:43Z',
#   '@elordyoitamiojermojanki7774',
#   'Really  on my Birthday is released date 😢😨😨😨',
#   0],
#  ['2025-04-03T22:21:51Z',
#   '@SuperCoily10230',
#   'I’m kinda disappointed. All the movies started out with some vehicular accident Airplane, Cars, Rollercoaster, Cars again and Bus I was hoping for something different like a Boat or a Cruise Ship or even Horse and Buggy',
#   1],
#  ['2025-04-03T22:13:57Z', '@mameshow725', '😢😢😢😢😮😅', 0],
#  ['2025-04-03T21:48:24Z', '@EddyEditsVFX', 'Opening day.', 0],
#  ['2025-04-03T21:40:54Z',
#   '@ordinaryusceren7679',
#   'My favourite film series😍😍❤️',
#   0],
#  ['2025-04-03T21:08:49Z', '@kendraalcantar4566', '😮', 0],
#  ['2025-04-03T21:07:02Z',
#   '@1nonlyabhi',
#   'Dread it, run from it, destiny still arrives all the same. ⏳',
#   1],
#  ['2025-04-03T20:39:29Z',
#   '@Panyirme',
#   'I have been ignoring this trailer for so long😢',
#   0],
#  ['2025-04-03T20:36:28Z',
#   '@Karol-g9d',
#   'Death is life buddy . Life is death buddy . Some of the things human think is downright wrong ! From life and death perspective',
#   0],
#  ['2025-04-03T20:21:46Z', '@shidqi1435', 'Tony todd RIP 🔥', 0],
#  ['2025-04-03T19:43:56Z',
#   '@noddygirl',
#   'We&#39;ve seen this 5 times already. Hollywood is creativity bankrupt.',
#   1],
#  ['2025-04-03T18:50:47Z', '@ms.23', 'GREAT trailer', 0],
#  ['2025-04-03T18:47:35Z',
#   '@ElijahGomez-666',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=132">2:12</a> Death: WANNA BET?',
#   1],
#  ['2025-04-03T18:45:46Z',
#   '@eatmyshorts7973',
#   'First it was the older man, then grandma, then Eric, then we will see where it goes from there.',
#   0],
#  ['2025-04-03T18:45:04Z', '@wantunsuganda', 'Pulu pulu pulu pulu pulu 😮', 0],
#  ['2025-04-03T18:21:39Z',
#   '@viraj5079',
#   'According to buddha, death is coming for everyone.',
#   0],
#  ['2025-04-03T18:16:35Z',
#   '@PeggySinkiewicz',
#   'And look out if you hear a John Denver song something bad is gonna happen',
#   0],
#  ['2025-04-03T18:06:11Z',
#   '@shankiawilliams997',
#   'I HAVE to see this! I&#39;ve seen every single Final Destination movie more than once. I thought it was over with the last one. I am very excited about this one.',
#   0],
#  ['2025-04-03T18:04:57Z',
#   '@AlexisStreams',
#   'new fear unlocked <br>glass shard and ICE',
#   0],
#  ['2025-04-03T17:57:31Z', '@Chartofkpop', 'I can&#39;t wait', 0],
#  ['2025-04-03T17:55:58Z', '@GWJ-p4m', 'Show respect for Tony Todd', 0],
#  ['2025-04-03T17:50:36Z',
#   '@SalimKhan-c5x2e',
#   'Your videos are always so helpful, thank you!',
#   0],
#  ['2025-04-03T17:38:12Z',
#   '@florestina864',
#   'Im so hoping for Wendy from FD 3 to return in the new movie... PLS PLS PLS',
#   0],
#  ['2025-04-03T17:35:44Z',
#   '@akshaykadam8136',
#   'My much awaited Hollywood movie ❤',
#   0],
#  ['2025-04-03T17:35:30Z',
#   '@BADANTERPALSOLAT',
#   'Sepi berdiri maka dingin maka dengar didengar bentar, tamak. Gatopik pendapat pisan didekati jarum mungkar.',
#   0],
#  ['2025-04-03T17:35:21Z',
#   '@BADANTERPALSOLAT',
#   'Sepi berdiri maka dingin maka dengar didengar bentar, tamak. Gatopik pendapat pisan didekati jarum mungkar.',
#   0],
#  ['2025-04-03T17:33:35Z',
#   '@Denise_in_progress',
#   'I don&#39;t know if this movie is gonna give me the same thrill  as the past ones, but hope I&#39;m wrong',
#   0],
#  ['2025-04-03T17:27:16Z',
#   '@khangchi2794',
#   'My heart rate is 140 bpm while im watching this trailer 😭',
#   0],
#  ['2025-04-03T18:26:50Z', '@Soredli', 'Youre diabetic?!', 0],
#  ['2025-04-03T17:11:13Z',
#   '@skipperhostile1345',
#   'Final Destination is immortal..',
#   0],
#  ['2025-04-03T17:08:28Z', '@bhagwanbharosse', 'RCB❤', 1],
#  ['2025-04-03T16:58:47Z',
#   '@tinoe936',
#   'Haven’t we seen enough of Final Destination, our childhood trauma is coming back to haunt us in our old age 😂😂😂😂',
#   0],
#  ['2025-04-03T16:45:55Z',
#   '@ArceeStarFan',
#   'Grim (Billy &amp; Mandy) &amp; Death (Puss in Boots) be like: 😏',
#   0],
#  ['2025-04-03T16:41:16Z',
#   '@Traveler12357',
#   'The first clip reminds me of Tom and Jerry😂',
#   0],
#  ['2025-04-03T16:39:24Z',
#   '@donaldsinkala3723',
#   'This Final Destination Bloodlines trailer is an intense, nerve-wracking ride that proves the franchise still knows how to deliver jaw-dropping horror. Right from the start, it sets an ominous tone, teasing a fresh batch of victims caught in Death’s relentless grip. The signature Rube Goldberg-style kills are back, more elaborate and brutal than ever, with the trailer showcasing just enough shocking moments to leave fans craving more. Final Destination fans brace yourselves. This one looks like a wild, bloody ride!',
#   0],
#  ['2025-04-03T16:01:46Z',
#   '@RonanJaPianist',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=122">2:02</a> RIP TONY TODD😢😢😢',
#   0],
#  ['2025-04-03T15:23:17Z',
#   '@andreg.ignacio',
#   'yes &amp; I don&#39;t care how bloody &amp; gory this movie is <br><br>im watching this once this released',
#   0],
#  ['2025-04-03T15:23:13Z',
#   '@Celticrose9999',
#   'I know its SO not the point of the line, but when he says &quot;Only by embracing Death will It pass you by&quot; I just wanna HUG HIM😭😭😭😭😭 RIP Tony Todd🐝🐝',
#   0],
#  ['2025-04-03T15:08:15Z', '@lodhiarmy', 'No logic on this movie', 0],
#  ['2025-04-03T14:51:35Z',
#   '@ポチョムキン-l5d',
#   'Are you going to go back to such a long time this time? (laughs)',
#   0],
#  ['2025-04-03T14:37:18Z',
#   '@KHThaArtist',
#   'Shards of glass or big pieces of glass my ptsd is what causing me to not what anything to do with ice🫠😭 thanks to the Warner Bros.',
#   0],
#  ['2025-04-03T14:26:38Z',
#   '@GeorgeWanganga-w2o',
#   'One of my favorites movies is back',
#   0],
#  ['2025-04-03T14:18:58Z', '@FTR007', 'When will it release?', 0],
#  ['2025-04-04T01:56:44Z', '@you-are-the-tharpsters', 'May 16 read please', 1],
#  ['2025-04-04T05:27:53Z',
#   '@FTR007',
#   '@you-are-the-tharpsters\xa0 <br>sorry broii<br>My mistake',
#   1],
#  ['2025-04-03T14:18:08Z', '@FTR007', 'Name is enough 😮', 0],
#  ['2025-04-03T14:12:35Z', '@Farhan_Ahmed76', 'Super', 0],
#  ['2025-04-03T14:12:30Z',
#   '@NicolasQuintero-i6q',
#   'I just realized that the song that is playing is when death is coming for them',
#   1],
#  ['2025-04-03T14:00:04Z',
#   '@voltrex_1327',
#   'It is time for another generation to become traumatized...',
#   0],
#  ['2025-04-03T13:19:26Z', '@MIna4Gym', 'Les gooo', 2],
#  ['2025-04-03T13:12:06Z',
#   '@thisisnotachannel',
#   'So this is a reboot?<br>Or is this supposed to have happened before the events of the first film?<br>Probably obfuscating on purpose... the first thought I had when I heard the sub-title &quot;Bloodlines&quot; was that it would be tied to the original in some way... but seemingly thats not the case.<br>I can&#39;t imagine I&#39;m the only person who had this thought... nor can I imagine that I&#39;m the only person who is seriously disappointed by this.<br>The original really is an all-time classic.<br>Oh well, at least you got Tony Todd one last time.<br>Rest in Peace, Candyman.',
#   0],
#  ['2025-04-03T12:58:56Z',
#   '@RM-EM',
#   'I&#39;ve never been excited to watch a movie!',
#   0],
#  ['2025-04-03T12:34:30Z',
#   '@mrstardian',
#   'So many different ways for that party to go wrong lol! Looks so good, glass in ice, spike under trampoline, and the lawnmower',
#   0],
#  ['2025-04-03T12:27:49Z', '@MustachoDude', 'Who drinks ice 🧊🧊🧊', 1],
#  ['2025-04-03T14:46:20Z',
#   '@eatmyshorts7973',
#   'You never put ice in the drinks or water?',
#   0],
#  ['2025-04-03T11:34:36Z',
#   '@tebogohamese4087',
#   'I can&#39;t wait to see what to avoid next in the forthcoming decades of my life.',
#   0],
#  ['2025-04-03T11:26:53Z',
#   '@ToxicKittiSP',
#   'Kind of ironic this is being produced after I first watched the first 5 films. Absolutely can’t wait to see a new final destination !!!',
#   1],
#  ['2025-04-03T11:26:50Z', '@ku.l', 'このドキドキ感堪らん。このシリーズでしか味わえない', 1],
#  ['2025-04-03T11:21:59Z',
#   '@DENISRO-jx5xv',
#   '&quot;where is MY supersuit&quot; ahh cover',
#   0],
#  ['2025-04-03T11:17:05Z',
#   '@ChaKho-c5x',
#   'Good luck is the best part I swear 😊',
#   0],
#  ['2025-04-03T10:55:53Z', '@luckysahotafilms6337', 'New fears Unlocked', 2],
#  ['2025-04-03T10:34:48Z',
#   '@tapuwamhondiwa5036',
#   'This movie always gave me goosebumps from the very first part of the truck loaded with logs snapping😂😂😂😂🙌🔥',
#   0],
#  ['2025-04-03T10:32:01Z', '@aashirhumayun8061', 'Heavy ❤', 0],
#  ['2025-04-03T10:29:44Z',
#   '@Archangel-91',
#   'I bet Tony Todd and Death met as friends 😢',
#   0],
#  ['2025-04-03T10:20:32Z',
#   '@edddeep',
#   'now its called perfect bloody sequel',
#   0],
#  ['2025-04-03T08:42:51Z',
#   '@samcruzznick',
#   'Final destination is still a running joke. and will keep you thinking. What if',
#   0],
#  ['2025-04-03T08:35:51Z', '@gvxx_', 'Wow', 0],
#  ['2025-04-03T08:27:39Z', '@shawnyang1971', 'Some weird coincidence', 0],
#  ['2025-04-03T08:18:46Z',
#   '@OverStuffedCookies',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=58">0:58</a> 😂😂😂😂',
#   0],
#  ['2025-04-03T08:12:10Z',
#   '@elisjord5928',
#   'Came here to only comment, meanwhile squinting my eyes to not see cause I don&#39;t want to be traumatized again !',
#   0],
#  ['2025-04-03T07:50:14Z',
#   '@juymrkitchen',
#   'nightmares from my childhood strikes again...',
#   1],
#  ['2025-04-03T07:27:16Z',
#   '@tallamvineethkumar2032',
#   'Get ready, a whole new generation will be traumatized forever',
#   1],
#  ['2025-04-03T07:12:38Z',
#   '@TomasVolley',
#   'Nah, saw the movie it feels like and not that exciting.',
#   0],
#  ['2025-04-03T07:02:49Z', '@MISTERORION', 'Day One.', 0],
#  ['2025-04-03T06:54:37Z',
#   '@sweethysteria8737',
#   'Wait wait wait what happened to new life upsetting the plan???<br>I guess that was a load of baloney…still makes final desti 2 feel a bit invalid now',
#   0],
#  ['2025-04-03T06:50:48Z', '@shagunverma23569', 'Main youtuber hun', 0],
#  ['2025-04-03T06:51:23Z', '@shagunverma23569', 'Nice🎉', 0],
#  ['2025-04-03T06:42:29Z',
#   '@PraiseDramaticOSTs',
#   'dude the glass in the ice such a succinct way to get under my skin 😂 — kudos to the filmmakers i’m checking all ice from now on',
#   0],
#  ['2025-04-03T06:40:31Z',
#   '@Trytobebetter969',
#   'Oh yeah, the transport trucks still scare me now when riding a motorbike:v',
#   0],
#  ['2025-04-03T06:26:30Z',
#   '@tofudubu0528',
#   'My tongue got cut/slightly poked by a sharp ice shard once. Never again.',
#   0],
#  ['2025-04-03T06:11:28Z', '@MrG25AmunRa', 'RIP To the great Tony Todd 😢', 0],
#  ['2025-04-03T06:09:54Z', '@DilipKumar-k870', '❤❤❤❤❤', 0],
#  ['2025-04-03T06:07:12Z',
#   '@Itsyasiiiir',
#   'whenever im behind the truck loaded wood no way man I always remember things',
#   0],
#  ['2025-04-03T05:23:30Z',
#   '@midlane757',
#   'Who thought the suburbs could be so dangerous',
#   0],
#  ['2025-04-03T05:22:12Z',
#   '@MrMcnamex',
#   'keep em coming. lol it took FD to make proper movie trailers. now run from death if you can lol',
#   0],
#  ['2025-04-03T05:20:22Z',
#   '@demontamerbf18',
#   'I would&#39;ve been seated watching on theaters either way, but I&#39;m glad they managed to give the same old plot a twist they have never done before with the person who had the premonition living long enough to have a family, that&#39;s really cool.',
#   0],
#  ['2025-04-03T05:02:07Z',
#   '@TTAgostinos',
#   'Just did a rewatch of the five movies and I was wondering if I could have a 6th movie. Great timing WB',
#   0],
#  ['2025-04-03T05:00:33Z',
#   '@VincentVo-qf7cu',
#   'Puss in the boots would say skill issue 💀😭',
#   0],
#  ['2025-04-03T04:00:20Z',
#   '@MLmusiclover1129',
#   'So they are the last family because grandma is the first in the death list but she cheat death that&#39;s why it skipped her. death come to every family or person that survive and it takes years to be her turn again..',
#   0],
#  ['2025-04-03T03:29:51Z', '@donovanfox7752', 'Calling it: someone dies', 0],
#  ['2025-04-03T03:28:21Z',
#   '@Chanchalkumari_4713',
#   'Be patient you will definitely get what is yours!!💖🎯😇',
#   0],
#  ['2025-04-03T02:39:23Z', '@itssweetclown', 'new trauma unlocked', 0],
#  ['2025-04-03T02:22:52Z',
#   '@Shrimpfriedry',
#   'Thanks for hanging in there for one last ride, Tony. 🥹❤️❤️❤️ I’m SO excited!',
#   0],
#  ['2025-04-03T02:22:31Z', '@Star_butterfly-fh2bw', '🐝🍬', 0],
#  ['2025-04-03T02:12:33Z',
#   '@Sav.3.',
#   'Wait I&#39;m confused, why does it go after the bloodline if we find out that in deleted scenes from the first movie and with confirmation from the second movie that creating new life cleans the slate.<br><br>If this all started with the grandmother and she had a family why is death  going after the family? Unless it&#39;s her time again or death is going backwards like in the second movie.<br><br>What about the other people that were saved from the premonitions, what about their bloodlines? <br><br>I have so many questions and I hope this movie has some of the answers, I&#39;m so excited.<br><br>I&#39;m glad to see this franchise return and I can&#39;t wait to see Dead Meat&#39;s kill count.',
#   0],
#  ['2025-04-03T03:20:36Z',
#   '@eatmyshorts7973',
#   'The other families were all dealt with and this one is the last.',
#   0],
#  ['2025-04-03T02:09:26Z', '@Daniel-no4np', '24 milhões de visualizações ❤', 0],
#  ['2025-04-03T01:57:23Z',
#   '@cribbles3476',
#   'As an adult, this makes me beyond excited. The Final Destination series is my favorite.',
#   5],
#  ['2025-04-03T01:41:11Z',
#   '@flyppster',
#   'Man, my anxiety, like driving behind a truck full of logs krept up again.',
#   0],
#  ['2025-04-03T01:39:19Z',
#   '@sentrycod2373',
#   'All these years, still can&#39;t write a good story',
#   0],
#  ['2025-04-03T01:39:11Z',
#   '@bihan7967',
#   'Oh god not another final destination movie lol',
#   0],
#  ['2025-04-03T01:24:32Z',
#   '@brandonmassingale6911',
#   'R.i.p to Tony Todd I’m gonna miss him he one of my favorite actor 😢',
#   0],
#  ['2025-04-03T01:04:22Z', '@charlottehiggins1651', 'RIP Tony todd 😢❤', 0],
#  ['2025-04-03T00:48:29Z',
#   '@DDRhappiness17',
#   'I have a feeling Alex Browning and Clear River are at the party the Grandmother attended',
#   0],
#  ['2025-04-03T03:21:23Z',
#   '@eatmyshorts7973',
#   'Clear was not part of the lineage',
#   0],
#  ['2025-04-03T00:12:18Z',
#   '@NicolásSanchez-v5r',
#   'Are nightmare have come back',
#   1],
#  ['2025-04-03T00:06:06Z',
#   '@sarahamon4318',
#   'kinda disapointed its not on a cruise ship',
#   1],
#  ['2025-04-02T23:32:32Z',
#   '@munchomonkey3003',
#   'This is actually an interesting concept for a sequel. The one who had the vision was the Grandma and she had it a long time ago, yet she was able to avoid death and have her own kids, but if she had died in the vision, then they wouldn&#39;t have existed so now. Death is after them because they were never meant to exist. That&#39;s actually a really interesting concept.',
#   1],
#  ['2025-04-02T23:08:21Z',
#   '@AngryDemonCat',
#   'Who goes to a tower with glass for a floor? Who builds that?',
#   1],
#  ['2025-04-02T23:06:57Z', '@sxrebondz', 'That one about to be EPIC!', 2],
#  ['2025-04-02T22:39:29Z',
#   '@BrayonLucas13',
#   'Very well made and agonizing trailer',
#   1],
#  ['2025-04-02T22:37:48Z',
#   '@davediaz1742',
#   'I never drive behind trucks on the highway',
#   1],
#  ['2025-04-02T22:25:22Z',
#   '@Smidgebomb',
#   'Highway crash just like the 2nd one please it&#39;s iconic',
#   2],
#  ['2025-04-02T22:23:06Z',
#   '@keyshiaceaserkaliku',
#   'Is that AI tony todd? Gotta be how gross',
#   1],
#  ['2025-04-02T21:51:55Z',
#   '@Ajax222able',
#   'Why do they spoil scenes that supposed to be sudden?',
#   1],
#  ['2025-04-02T21:31:06Z',
#   '@LulisaLulisa',
#   'I&#39;m from the generation of the logs on the back of the truck. I say to the new generation,  good luck to you all 😂😂 stay strong 💪 you got this 😂',
#   2],
#  ['2025-04-02T21:17:10Z', '@AzadMishra21', 'My fav series', 1],
#  ['2025-04-02T20:48:42Z',
#   '@CatChaos369',
#   'Seeing Tony Todd is bittersweet bless him.',
#   1],
#  ['2025-04-02T20:46:25Z', '@Hadegard', 'Can&#39;t wait. Awesome 🔥', 1],
#  ['2025-04-02T20:26:25Z',
#   '@AJxxxxxxxx',
#   'So if you cheat death then death will just come after your descendent, there’s no escaping it',
#   1],
#  ['2025-04-02T20:17:07Z',
#   '@nomizat9553',
#   'Damn its release date is same with my birthday,I guess they will witness my birth',
#   1],
#  ['2025-04-02T20:06:44Z',
#   '@teminternetemmordor7178',
#   'Dude serious? C&#39;mon, everybody know&#39;s what happens when you don&#39;t respect basic OSHA rules at this poin. 🤦🤦🤦',
#   1],
#  ['2025-04-02T20:05:15Z', '@midnightejv', '🤍🖤', 1],
#  ['2025-04-02T19:54:59Z', '@animating_sleeping', 'scary 🥶 ❗', 1],
#  ['2025-04-02T19:53:29Z',
#   '@CJMarkus',
#   'Now, this is a proper send-off for Tony Todd',
#   0],
#  ['2025-04-02T19:50:14Z',
#   '@denizaygün-l1k',
#   'Final destination of the best horror franchise',
#   0],
#  ['2025-04-02T19:29:24Z',
#   '@KSlayXTyn',
#   'I hate when they give away the death scenes 😢',
#   0],
#  ['2025-04-02T18:57:08Z', '@DReed-bg2gi', 'Gotta see it🔥🔥', 1],
#  ['2025-04-02T18:28:32Z',
#   '@albertpuppymaster671',
#   'Why do they keep doing reboots for fuvks sake. 😂',
#   0],
#  ['2025-04-02T18:10:09Z', '@muhzinmuzi5255', 'Waiting 🔥🔥🔥', 0],
#  ['2025-04-02T18:01:54Z',
#   '@Fumbanijr',
#   'Ooohh this is about to be real good',
#   0],
#  ['2025-04-02T17:51:26Z',
#   '@jellyfufu',
#   'bro whats crazy is that I got this trailer from a add I was to busy to skip but as soon as I heard &quot;death&quot; I flipped out I been in love with the final destination movies I cant wait to see how this one plays out (also cant wait for new fears DAMN) AAA HYPED',
#   1],
#  ['2025-04-02T17:40:13Z',
#   '@EnriqueGarcía-f6h',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=100">1:40</a> Missed opportunity to include &quot;Death, doesn&#39;t like to be cheated&quot;',
#   1],
#  ['2025-04-02T17:36:02Z',
#   '@smurfchina6147',
#   '90s kids are giggling right now',
#   1],
#  ['2025-04-02T17:35:32Z',
#   '@karankaushik3006',
#   '&quot;dust in the wind&quot;',
#   0],
#  ['2025-04-02T17:31:39Z',
#   '@jessediaz1293',
#   'I only want to watch this because it’s Tony Todd’s last film.<br><br>RIP Candyman',
#   1],
#  ['2025-04-02T17:09:30Z', '@kerrajohnson3203', 'no.', 0],
#  ['2025-04-02T16:58:52Z',
#   '@punnil-on4918',
#   'So crazy when you realize that In that time the grandma save everyone life is the butterfly effect that make the story begin from 1-5 💀',
#   2],
#  ['2025-04-02T16:51:05Z',
#   '@D-MF-L',
#   'Finally somebody other than Peter Jackson uses a lawnmower as an instrument of permanently unaliving',
#   0],
#  ['2025-04-02T16:44:27Z', '@sarthakshivpuje967', 'Soo excited', 0],
#  ['2025-04-02T16:38:21Z', '@SandyinYoutube', '🥶🥶🥶', 1],
#  ['2025-04-02T16:03:00Z',
#   '@abhimanyumukundhan9547',
#   'No malayalies….. no way 💥',
#   0],
#  ['2025-04-02T15:51:16Z',
#   '@user-funtv8',
#   'Single malt, atleast 12 year&#39;s, straight or frappe😂.',
#   0],
#  ['2025-04-02T15:49:45Z',
#   '@BlueNukez',
#   'oh boy! time for the next generation to get some irrational fears',
#   0],
#  ['2025-04-02T15:22:49Z',
#   '@Pickle_Me_Elmo',
#   'RANBOO, WHAT ARE YOU DOING ON MY BIRTHDAY? (my birthday&#39;s May 26th)',
#   0],
#  ['2025-04-02T15:21:31Z',
#   '@XiaphasGames',
#   'So, do we not put the trailer disclaimers at the start of trailers anymore?',
#   0],
#  ['2025-04-02T14:56:14Z',
#   '@TonyTallDarkWerewolf',
#   'Isn’t the not looking while walking backwards to a open road while talking only to expect getting hit a little overused and old already 😂',
#   1],
#  ['2025-04-02T14:48:12Z',
#   '@FinalFrontier101',
#   'I&#39;m actually going to a movie theater to watch this peak. Absolute cinema it must be seen on the big screen.',
#   1],
#  ['2025-04-02T14:13:23Z',
#   '@shawn5484',
#   'gila ini film gapernah gagal kalo buat degdegan Anjj 💥🔥',
#   0],
#  ['2025-04-02T14:12:29Z', '@TrenchCoatGang', 'Two IMAX Tickets Please 🎟️', 2],
#  ['2025-04-02T14:01:52Z',
#   '@watchatoon317',
#   'It reminds meto stay away from trucks carrying logs',
#   2],
#  ['2025-04-02T13:11:54Z', '@JesusVEIVO', 'Thank you priest', 2],
#  ['2025-04-02T12:44:08Z',
#   '@CJPLA',
#   'This might have the record for most tropes possible - the book of secrets, crazy old wise person that can see the future, map on wall, haunting rendition of classic song, etc. etc. etc.',
#   1],
#  ['2025-04-02T13:53:52Z',
#   '@Soredli',
#   'Iris cannot see into the future. Not sure where you got that from but sure bud.',
#   0],
#  ['2025-04-02T12:37:05Z',
#   '@ReubenTan-vm3te',
#   'This all started because they banned straws',
#   0],
#  ['2025-04-02T12:16:34Z', '@KEEPMYiNYUSWTCHUT', 'Here you go finally❤', 0],
#  ['2025-04-02T11:52:21Z', '@CumaliOzturker', 'özlemiştik', 0],
#  ['2025-04-02T11:51:38Z',
#   '@anthonyarcanumsanctumregnu9551',
#   'Its sad You couldntell Tony was sick in this clip because He lost so much weight He didnt look well He was a nice weight to begin with nice and slim here He was mad skinny, its a shame may He Rest in peace!',
#   0],
#  ['2025-04-02T11:46:46Z',
#   '@lauramarie8485',
#   'Why why why now I got to avoid more things at home 💀💀💀💀💀',
#   0],
#  ['2025-04-02T11:18:49Z',
#   '@belluhh525',
#   'thanks to you, when I hear dust in the wind I get goosebumps',
#   0],
#  ['2025-04-02T11:04:10Z',
#   '@SehansaFernando-yo5ku',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=51">0:51</a>',
#   0],
#  ['2025-04-02T10:49:45Z', '@Spinmoney525', 'The door 😭💀', 0],
#  ['2025-04-02T10:48:52Z',
#   '@ZioHaruke-w1k',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=67">1:07</a>  that scream was everything',
#   0],
#  ['2025-04-02T10:12:13Z',
#   '@BABYDOLL87LOVELY',
#   'I HAVE THE OTHER 5 IN MY GIANT COLLECTION. CAN&#39;T WAIT TO SEE IT!',
#   0],
#  ['2025-04-02T09:59:25Z',
#   '@ciiil8802',
#   'Final destination ❌<br>Final Human Stupidity ✅',
#   0],
#  ['2025-04-02T09:41:36Z',
#   '@titanialisbeth6967',
#   'Daamn duuude we&#39;re here again 🔥',
#   1],
#  ['2025-04-02T09:41:33Z', '@InfoGraphy1932', 'Finally comeback 😍', 0],
#  ['2025-04-02T08:55:14Z',
#   '@cliefordcruz3782',
#   'Oh god really ? Wait i need to hold my breath now',
#   0],
#  ['2025-04-02T08:35:42Z',
#   '@Preslycode',
#   'ONCE I SAW THAT BOOK I KNEW IT WAS A WRAP LOL',
#   0],
#  ['2025-04-02T08:18:50Z', '@craigsanjivygan215', 'Looks cheesey.', 0],
#  ['2025-04-02T08:06:12Z', '@jenny_mm', 'Song name please', 0],
#  ['2025-04-02T08:05:22Z', '@green4ao', 'Криворукие американцы.', 0],
#  ['2025-04-02T13:54:35Z', '@Soredli', 'Thats a fillipina and asian', 0],
#  ['2025-04-02T08:04:50Z', '@prabhash8979', 'Death😎😎😎😎', 0],
#  ['2025-04-02T07:31:17Z',
#   '@Chickens635',
#   'BROKEN GLASS IN ICE :<br><br>New fear unlocked : 😭😭🚶🏽\u200d♀️',
#   1],
#  ['2025-04-02T07:12:25Z', '@loganbro5945', 'Rip Tony Todd 😢 🙏 💔', 1],
#  ['2025-04-02T06:55:02Z',
#   '@ItsChandan28',
#   'No Destination In Final Destination',
#   1],
#  ['2025-04-02T06:53:20Z',
#   '@allandemwenyewe',
#   '😅😅😅😅😅😅😅 I really like The Final Destination....all of them I&#39;ve watched and they are really funny how the deaths are well arranged👍🏼👍🏼👍🏼👍🏼👍🏼<br>Make it a series I&#39;ll enjoy even more',
#   0],
#  ['2025-04-02T06:53:14Z',
#   '@BratCity',
#   'Can you imagine how paranoid one has to be to make an entire film series like this? 💩',
#   0],
#  ['2025-04-02T13:54:59Z',
#   '@Soredli',
#   'Uhh no the creator is not paranoid he likes writing',
#   0],
#  ['2025-04-02T06:38:29Z',
#   '@AmbroseBrandt',
#   'Well that&#39;s the last time I visit the space needle 😂',
#   0],
#  ['2025-04-02T06:33:07Z',
#   '@rachelknightonline',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=17">0:17</a> <br><br>I once ate some nachos, and swallowed the piece of chip at what I can only assume was that angle, and felt it go down my throat and it hurt SO bad. <br><br>Way to go movie for making me realize that could’ve been infinitely worse',
#   0],
#  ['2025-04-02T06:28:31Z',
#   '@KokoKrunchs',
#   'Oh here we go again, the journey to add more trauma and fear in my life 🎉',
#   0],
#  ['2025-04-02T06:17:30Z',
#   '@KassyTravels',
#   'That truck with logs started it all',
#   0],
#  ['2025-04-02T06:13:34Z',
#   '@The-gamer-girl-official',
#   'Wow I got Goosebumps..  ..... Amazing ..',
#   0],
#  ['2025-04-02T05:30:10Z',
#   '@brentcastro10987',
#   'This looks kinda cheesy like The Final Destination😬',
#   0],
#  ['2025-04-02T04:57:15Z',
#   '@Gfabu',
#   'I just know this gonna be so corny ugh. They just haven&#39;t been great since the 3rd',
#   0],
#  ['2025-04-02T04:36:11Z',
#   '@BraQKun',
#   'Women should really scream louder every time. It really helps solve the situation.',
#   0],
#  ['2025-04-02T03:56:23Z', '@AFBasketball3', 'yo f that log truck', 0],
#  ['2025-04-02T03:41:25Z', '@sweetcinnamonpnchkin', 'Death: creative mode', 0],
#  ['2025-04-02T03:00:37Z',
#   '@akhilbhadani9050',
#   'When they find new ways to kill brutally... They just make a final destination series movies...',
#   1],
#  ['2025-04-02T02:29:38Z',
#   '@rohitpatravale9973',
#   'The Final Destination franchise gave me horror for roller coaster rides. Never sat in them throughout my life. 😭😂',
#   0],
#  ['2025-04-02T02:08:24Z',
#   '@Bananaduck_YT',
#   'I am waiting.. this series is good',
#   1],
#  ['2025-04-02T02:03:51Z', '@LUCENOJUNELN.', 'I&#39;m so excited for this😮', 1],
#  ['2025-04-02T01:51:36Z', '@HACPOA-0004', 'YOOO!! The franchise is back!', 0],
#  ['2025-04-02T01:45:49Z',
#   '@TeknoBlast',
#   'I just finished watch the first 5 FD movies. Now I&#39;m ready for the next!',
#   0],
#  ['2025-04-02T01:37:56Z', '@li-ln2or', 'Imran Khan ko riya karo', 0],
#  ['2025-04-02T01:34:36Z',
#   '@ellee2685',
#   'Oh boy. A whole new generation gets to be emotionally and psychologically scarred. I still don&#39;t drive behind lumber trucks, BTW',
#   1],
#  ['2025-04-02T01:07:22Z',
#   '@thechaostheory3397',
#   'Trampoline sales about to go down lmfao',
#   0],
#  ['2025-04-02T01:06:19Z',
#   '@ultimatesunrise',
#   'i miss tony todd so f&#39;n much dude... i met him once at Shock-a-Con and he talked with me for like 10 mins and signed my candyman dvd and figure.  Great dude.. Rest easy champ..',
#   5],
#  ['2025-04-02T00:40:46Z',
#   '@toby4186',
#   'I’m just not gonna watch it…<br>I don’t want to live paranoid for the rest of the decade AGAIN',
#   0],
#  ['2025-04-02T00:20:51Z',
#   '@necroblaze8771',
#   'Whats most scariest  and different of all  the final destination franchise movie from all the other horror movies is that this stuff is real accidental stuff that can happen to us, unlike movies about ghosts and possessed people these movies everyone can relate too',
#   5],
#  ['2025-04-01T23:07:55Z',
#   '@AaronIsaacVasquez',
#   'Bro death is doing too much. A simple heart attack will do',
#   2],
#  ['2025-04-01T23:50:57Z',
#   '@The-only-Superman-that-matters',
#   'Ikr😂Ffs Even John The Angel of Death off Touched by The Angel gives his victims heart attacks without being so cruel 😂',
#   0],
#  ['2025-04-02T00:17:25Z',
#   '@joewhitehead3',
#   'They say life is a b***h. But more like death is a b***h',
#   0],
#  ['2025-04-02T13:59:13Z',
#   '@Soredli',
#   'Do you not get it? By surviving death, you broke his plan, and he gives you a much worser fate and death than your original, goofy.',
#   0],
#  ['2025-04-01T23:01:49Z', '@jalish.mahmud', 'Goosebumps', 0],
#  ['2025-04-01T22:55:19Z',
#   '@greedsongwriter',
#   'New fear unlocked glass in ice ffs',
#   1],
#  ['2025-04-01T23:48:55Z',
#   '@The-only-Superman-that-matters',
#   'I just came out of Zaxby&#39;s after pouring out ice and into my drink without checking😬',
#   0],
#  ['2025-04-02T19:45:25Z', '@greedsongwriter', '@ taking a risk there 😱', 0],
#  ['2025-04-01T22:53:44Z', '@anthonyknight2124', 'Candy man', 2],
#  ['2025-04-01T22:31:16Z',
#   '@zendricksvargas',
#   'finally, after 14 years! everyone is very excited!',
#   0],
#  ['2025-04-01T23:43:12Z',
#   '@ccMomOfJays',
#   'I haven&#39;t been able to get my kids to watch the originals (19&amp;24) but they taking me to watch this one!',
#   1],
#  ['2025-04-01T23:56:06Z',
#   '@The-only-Superman-that-matters',
#   '\u200b@@ccMomOfJays U raised them well😂I&#39;m taking my mom to see this movie and she&#39;s a huge horror movie fan. But me being a small child in the 2000s my mom wouldn&#39;t let me see the first 3 movies😂',
#   0],
#  ['2025-04-01T22:22:09Z',
#   '@random-mj9bx',
#   'The bartender in me got so disappointed, I mean yea ik it&#39;s a movie but if u break glass that near burn the well immediately 😂😭',
#   0],
#  ['2025-04-01T21:32:30Z',
#   '@rhondarostrickland4665',
#   'So now y&#39;all bout to have us scared to eat ice, well that&#39;s just fabulous 😂.  RIH Tony Todd, you and your iconic voice will be missed 🕊️🕯️🙏🏽🫶🏽',
#   1],
#  ['2025-04-01T21:32:21Z',
#   '@rhondarostrickland4665',
#   'So now y&#39;all bout to have us scared to eat ice, well that&#39;s just fabulous 😂.  RIH Tony Todd, you and your iconic voice will be missed 🕊️🕯️🙏🏽🫶🏽',
#   0],
#  ['2025-04-01T20:54:18Z',
#   '@wonderthursday',
#   'Seriously Love them all, RIP Tony (Candyman) Todd, the best. Now i know never to put Glass near Bags of Ice....',
#   0],
#  ['2025-04-02T00:18:00Z',
#   '@joewhitehead3',
#   'Best to get ice directly from the freezer',
#   0],
#  ['2025-04-01T20:50:27Z',
#   '@ihadlunch8575',
#   'Ah the movie series that made me afraid to walk outside and not trust outlets.',
#   1],
#  ['2025-04-01T20:49:53Z',
#   '@runnames',
#   'Will this movie be 3D? 4DX availability',
#   1],
#  ['2025-04-01T23:52:22Z',
#   '@The-only-Superman-that-matters',
#   'I hope so😊 🙏🏻',
#   0],
#  ['2025-04-01T20:33:17Z', '@ghostpanda66', 'pls made 3D 😍😍😍😍😍😍🤩🤩', 0],
#  ['2025-04-01T20:32:39Z',
#   '@abhiz9922',
#   'New gen Ain&#39;t ready for this 😭😭',
#   0],
#  ['2025-04-01T20:16:38Z',
#   '@Miekolia',
#   'Im so excited! I&#39;ve been waiting for another one of these !!',
#   0],
#  ['2025-04-01T19:58:11Z',
#   '@lepaul_Official',
#   'what happend to the medieval setting? <br>this just looks awful',
#   0],
#  ['2025-04-01T19:54:31Z', '@pjsherpa', 'yoy guys scared bc im ughh heheh', 1],
#  ['2025-04-01T19:53:48Z', '@LinCoxx-p2v', 'Play for the 25 million', 0],
#  ['2025-04-01T19:40:07Z',
#   '@PositivePlanet2025',
#   'I just saw there was an accident on the road. There was a man or woman got hurt. He saved somebody’s life before I guess. Probably, he couldn’t cheat a death🫣🫣🫣',
#   0],
#  ['2025-04-01T19:24:39Z',
#   '@onlytrixxowo',
#   'GREAT MOVIES I LOVE IT ALL OF THEM MY CHILDHOOD but kinda lame deaths ngl some are good i dont say its bad but cmon we had already a lady that died in the elevator and he has the same death, even the truck death bro is so common<br>As I said its really great and i cannot wait to see the movie love it but wish there would be some rly bloody, horrible deaths',
#   0],
#  ['2025-04-01T19:18:09Z',
#   '@ec9121',
#   'It&#39;s gonna be so horrible and I can&#39;t wait!',
#   0],
#  ['2025-04-01T18:57:08Z',
#   '@mounirmugen3900',
#   'i can predict that three chars are dead : the man with tattos in the first official trailer ; the woman trapped in building entrance glass door and of course the father named howard ; the rest no clues for their deaths',
#   0],
#  ['2025-04-01T18:54:29Z', '@Weedy_McWeedy', 'R.I.P. Tony Todd. 🙏🏻✌🏻❤️', 0],
#  ['2025-04-01T18:47:52Z', '@sd795', 'All part is awesome 💯😎', 0],
#  ['2025-04-01T18:12:11Z', '@HarisAli-yr9lw', 'Damn yes', 0],
#  ['2025-04-01T18:07:57Z',
#   '@manthanpatel1890',
#   'Brother is genius he carried decades long story😂😂',
#   0],
#  ['2025-04-01T18:01:26Z',
#   '@berryw1315',
#   'RIP Tony Todd will be missed a film legend',
#   0],
#  ['2025-04-01T17:51:03Z',
#   '@KickAss5671',
#   'Candyman looks like he has Gatoraids',
#   0],
#  ['2025-04-01T17:47:43Z',
#   '@CharlesmattRaya',
#   'And i don&#39;t know but maybe the new generation will expirience what 2000&#39;s kid feel.',
#   0],
#  ['2025-04-01T17:43:17Z',
#   '@CharlesmattRaya',
#   'Why none any of them consult anyone who deal&#39;s with magic.',
#   0],
#  ['2025-04-01T17:29:16Z',
#   '@freewilldummies1603',
#   'Recently did a final Destination marathon 😊, ended up watching Countdown again too.',
#   1],
#  ['2025-04-01T17:26:01Z', '@youaremine-c6e', 'Can&#39;t wait to see 😆', 0],
#  ['2025-04-01T17:21:08Z',
#   '@koolaidman5661',
#   'Welp, there goes my will to visit CN Tower once more 💀',
#   0],
#  ['2025-04-01T17:14:35Z', '@AsadAli-wu9bh', 'Waiting', 0],
#  ['2025-04-01T16:52:16Z', '@KB-dr1vu', 'I CAN&#39;T WAIT!!', 1],
#  ['2025-04-01T16:19:15Z',
#   '@sirenscreams',
#   'RIP Tony Todd. It looks like they found a good replacement. He kinda looks and sounds like him.',
#   0],
#  ['2025-04-01T16:12:43Z',
#   '@andyz6566',
#   'It&#39;s seems like stefanie and charlie are gonna be the last characters to live',
#   0],
#  ['2025-04-01T15:56:01Z', '@god563616', 'Tony Todd Your a real one. 😭', 0],
#  ['2025-04-01T15:54:01Z',
#   '@lennymomanyi7104',
#   'I have heard about those jokes... At the end of the day, something must kill a man. It could be you next',
#   0],
#  ['2025-04-01T15:32:29Z',
#   '@Resso3-qz1lz',
#   'The wrong can happen ,Will happen',
#   0],
#  ['2025-04-01T15:31:02Z', '@fioredigelsamino2557', 'Im ready !!!!!!', 1],
#  ['2025-04-01T15:12:45Z',
#   '@ot50340',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=131">2:11</a> john Murphy',
#   0],
#  ['2025-04-01T15:00:11Z',
#   '@rioguttaful',
#   'the last movie came out 20 years ago man time sure does fly yet we all are here',
#   1],
#  ['2025-04-01T14:48:17Z',
#   '@boobyari4916',
#   'The only movie that scares you to death and still have you wanting to laugh a little once you&#39;re done screaming',
#   0],
#  ['2025-04-01T14:44:30Z',
#   '@meyimiogidan8152',
#   'The best horror movie ever!!!!',
#   1],
#  ['2025-04-01T14:41:08Z',
#   '@egads3696',
#   'Damn it this is the second trailer ive watched in a row, that means ill get nothing but trailers recomended for a week.',
#   0],
#  ['2025-04-01T14:38:06Z',
#   '@MaTangTat',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=132">2:12</a> That&#39;s a cliche, very predictable~',
#   0],
#  ['2025-04-01T14:37:05Z',
#   '@shaunfrench7712',
#   'This somewhat reminded me of an episode from Supernatural where an angel went back in time to prevent the Titanic from hitting the iceberg. But decades later one of the three Fates started killing the descendants of those people who survived but weren&#39;t supposed to. She did that because they weren&#39;t supposed to exist. Those descendants died in freak accidents.',
#   0],
#  ['2025-04-01T14:23:48Z',
#   '@shaunfrench7712',
#   'If they decide to do another one, the main catastrophe should happen at  a wedding,moments after a groom accidentally saw his bride to be.',
#   0],
#  ['2025-04-01T14:04:13Z',
#   '@What-T-H-E-Phuck',
#   'They recreated the bus scene of course they did',
#   0],
#  ['2025-04-01T13:46:06Z',
#   '@yourtravellab',
#   'The glass in the ice.. God.. Scared me.. 😮',
#   0],
#  ['2025-04-01T13:38:20Z',
#   '@bizzlowthxx',
#   'No thanks, i dont need to introduce myself another trauma.',
#   2],
#  ['2025-04-01T13:20:42Z',
#   '@Cocoshort2257',
#   'Is everyone using the Jordan Pele horror soundtrack now?',
#   0],
#  ['2025-04-01T13:07:26Z',
#   '@glitche7710',
#   'Reminder: its only a week and it already racked up 23mil views',
#   1],
#  ['2025-04-01T12:43:33Z',
#   '@eatmyshorts7973',
#   'Do you know how many people there were on that tower?',
#   0],
#  ['2025-04-01T12:43:18Z',
#   '@Name.Surname',
#   'I watched the whole movie in one trailer, thank you',
#   0],
#  ['2025-04-01T12:43:50Z', '@eatmyshorts7973', 'Then explain every detail', 2],
#  ['2025-04-01T12:42:10Z',
#   '@enrichogabrielgandhisihomb3321',
#   'Old lady : I PLAYED THESE GAMES BEFORE',
#   1],
#  ['2025-04-01T12:40:54Z',
#   '@KitKatRocks1984',
#   'Tony Todd, The Man, The Myth, The Legend. Rest In Peace Tony.',
#   0],
#  ['2025-04-01T12:36:31Z', '@あや-d9h5g', '楽しみ過ぎる😆👍', 0],
#  ['2025-04-01T12:11:53Z',
#   '@brianmolele7264',
#   'Crazy thing is that I was thinking about this franchise the other day, I was like why don&#39;t they continue to make another one. I was watching a documentary on ship rope snapbacks, then I thought about this movie.',
#   1],
#  ['2025-04-01T12:11:53Z',
#   '@6daneo',
#   'WOW PERFECT 3D ALL THE WAY. BUT I STILL LIKE THE LOG FALLING OUT OF THE TRUCK LIKE ITS REAL',
#   0],
#  ['2025-04-01T11:53:01Z',
#   '@Tummyachesurvior',
#   'Not me thinking this was a video game because the thumbnail looked animated',
#   0],
#  ['2025-04-01T16:15:23Z', '@Soredli', 'HELP youre not wrong', 0],
#  ['2025-04-01T11:40:04Z',
#   '@alltypevideo6414',
#   'My childhood favourite movie is back 🥹',
#   0],
#  ['2025-04-01T11:26:42Z',
#   '@flygerianfly2508',
#   'I can&#39;t even watch the thriller 😂... I can&#39;t ..... Tis too much for me',
#   0],
#  ['2025-04-01T10:53:18Z', '@andreluiz_n', 'R.I.P', 0],
#  ['2025-04-01T10:52:25Z',
#   '@dandembele7555',
#   'RIP Tony Todd - Better known as Candyman 🌟🙏🏾🌟',
#   0],
#  ['2025-04-01T10:41:35Z', '@JoleneHipol', 'i-is this fake?', 0],
#  ['2025-04-01T10:42:20Z',
#   '@JoleneHipol',
#   'i was always afaraid of tsunamis… and im going to the beach on friday april,2025',
#   0],
#  ['2025-04-01T16:15:58Z',
#   '@Soredli',
# ...
#   '20 million view in 4 days <br><br>Yes this franchise is so interesting',
#   0],
#  ['2025-03-30T11:23:12Z',
#   '@theeorangelemon',
#   'Honestly I don’t think this is real, I feel like I’ve seen everything imma see in the movie from the trailer',
#   0],
#  ['2025-03-30T11:07:29Z',
#   '@longo.0063',
#   'Looks good, but one question: doesn&#39;t that cancel the rule from part 2? yk new life defeats death',
#   0],
#  ['2025-03-30T15:16:34Z',
#   '@GiaHoaNguyen',
#   'Each installment has a different rule (like FD5: off another one to take their lifespan).<br><br>I don&#39;t really care, though (the plot ain&#39;t that good to begin with, and it&#39;s been like that for far too long). As long as the deaths are creative, then I&#39;m good.',
#   0],
#  ['2025-03-30T11:02:33Z',
#   '@Harshitau4q',
#   'Final destination ❌final death💀 ✅',
#   0],
#  ['2025-03-30T11:02:11Z',
#   '@_kallmebless',
#   'I hate Final Destination but I always find myself watching any of the movies, eventually I’ll watch this one too😭😭',
#   0],
#  ['2025-03-30T15:18:10Z',
#   '@GiaHoaNguyen',
#   'Tbh, the plot ain&#39;t that good to begin with, but it&#39;s unique (and reusable). And I get hooked because of the deaths, not the plot. Guess the same goes for you.',
#   0],
#  ['2025-03-30T11:01:04Z',
#   '@revaneswaranmuniandy',
#   'Guys pour your opinion  on this. Will it be good in 4dx?',
#   0],
#  ['2025-03-30T10:43:50Z',
#   '@foodietechno',
#   'Its been more than 2 decades now and I still can&#39;t drive behind a truck full of logs/pipes',
#   1080],
#  ['2025-03-31T21:25:58Z', '@pica2754', 'Same!', 9],
#  ['2025-04-01T12:26:59Z', '@luqmxxxn', 'Me too 😂', 5],
#  ['2025-04-01T15:28:08Z', '@tegar.novaliano9589', 'same 😂', 4],
#  ['2025-04-02T06:33:24Z', '@Shantia-v4w', 'Me neither', 2],
#  ['2025-04-02T20:07:44Z', '@vivekshah3170', 'fr', 0],
#  ['2025-03-30T10:42:33Z', '@ctrmtlofficial3331', 'Omg!!!!😂', 1],
#  ['2025-03-30T10:40:00Z',
#   '@amansrann5988',
#   'Fatt gai bhailog.. apun nahi dekhega..',
#   1],
#  ['2025-03-30T10:24:03Z',
#   '@bhimsingh8459',
#   'get ready GenZ for a lifetime trauma',
#   0],
#  ['2025-03-30T10:19:19Z', '@eloooyhm832', 'Here we go again ☕', 0],
#  ['2025-03-30T10:15:29Z',
#   '@fhdartz',
#   'It’s hard to edit a trailer with this franchise without giving away too much',
#   0],
#  ['2025-03-30T10:14:58Z',
#   '@-Tasleem',
#   '&quot;&quot;May 16 &quot;&quot;&quot;---- it&#39;s my birthday dude😢......',
#   0],
#  ['2025-03-30T10:13:44Z',
#   '@nicholasgerry6931',
#   'This family is especially clumsy holy... 🤦🏻\u200d♂️',
#   0],
#  ['2025-03-30T10:09:12Z',
#   '@halewolf3800',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=15">0:15</a> The sound design in this trailer is amazing. That noise is so eerie. It sets off my anxiety, I love it xD',
#   3],
#  ['2025-03-30T10:06:18Z',
#   '@samaxe9088',
#   'Welcome to my generation young ppl when movies were ACTUALLY GOOD !!!',
#   0],
#  ['2025-03-30T09:59:43Z', '@BiniuPdz', 'Death, death, and more death', 0],
#  ['2025-03-30T09:58:32Z',
#   '@rillawhat8142',
#   'Anxiety just watching the trailer',
#   0],
#  ['2025-03-30T09:45:43Z',
#   '@successornothin',
#   'I still don&#39;t drive behind log trucks...now I have to inspect my ice..yay..',
#   0],
#  ['2025-03-30T15:22:06Z',
#   '@GiaHoaNguyen',
#   'Guess I&#39;ll just avoid the ice completely. :((<br><br>Btw, we had nose ring and lawnmower on the black list already. Let&#39;s see what else we&#39;ll find out.',
#   0],
#  ['2025-03-30T09:44:59Z', '@DJよしくん', 'ファイナルデスティネーションの新作きたか🤩', 0],
#  ['2025-03-30T09:41:10Z',
#   '@mdabutayeebOnDuty',
#   'The priest looks like Frozone',
#   1],
#  ['2025-03-30T15:23:30Z',
#   '@GiaHoaNguyen',
#   'Priest? I thought William Bludworth is the undertaker (mortician).',
#   0],
#  ['2025-03-30T09:38:59Z', '@agumaduiheanyi188', 'Wow, 😮', 0],
#  ['2025-03-30T09:33:55Z',
#   '@kk_fr0gger',
#   'it feels kinda cursed seeing Final Destination in such good quality because I always associated the movies with bad CGI and film quality they had at the time. super excited for what they might have in store!',
#   1],
#  ['2025-03-30T09:33:35Z',
#   '@Shiturin',
#   'I love that they showed us half of the deaths scenes in one trailer 🥰',
#   0],
#  ['2025-03-30T09:25:09Z',
#   '@muhammadrakamalsi',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=108">1:48</a> This pictures look like in :<br>Final Destination 2 : Highway<br>Final Destination 1 : Airport',
#   0],
#  ['2025-03-30T09:18:08Z',
#   '@coutoalberton3123',
#   'Is it me or this trailer just spoied the whole movie?',
#   0],
#  ['2025-03-30T09:16:25Z',
#   '@dbolden2006',
#   'Does Anyone Know What Anxiety Is???',
#   0],
#  ['2025-03-30T09:10:18Z',
#   '@LukeKnightceus',
#   'This is what Marvel intended to do when they planned to introduce Death into the MCU and give this character their own movie',
#   0],
#  ['2025-03-30T09:09:42Z', '@kriscarrdublr', 'RIP Tony Todd', 0],
#  ['2025-03-30T08:59:20Z',
#   '@hendrihermawan6651',
#   'Udah ngga sabar pengen nonton',
#   0],
#  ['2025-03-30T08:58:26Z',
#   '@zeusdunpeal8809',
#   '‘No one escapes Death ‘ I hope the Apalca generation will cry when they’ll see this movie 😂',
#   0],
#  ['2025-03-30T08:55:40Z',
#   '@tafadzwachinhengo1237',
#   'I rewatched the whole franchise 2 months ago, i was happily re-traumatized! And this, this i gotta watch in a theatre, May 16, count me in! Release the trauma!!!!',
#   0],
#  ['2025-03-30T08:54:59Z',
#   '@RemingSt33l',
#   'Are you serious!!! The cgi is so bad it&#39;s practically in every damn scene... Ridiculous definitely not watching',
#   0],
#  ['2025-03-30T09:14:09Z', '@SocialExhaustion', '???', 0],
#  ['2025-03-30T08:52:02Z',
#   '@0KarlAdrian0',
#   'Then: being afraid of roller coasters and trucks<br>Now: being afraid of ice in drinks',
#   0],
#  ['2025-03-30T08:49:04Z', '@jhonsabanal8264', 'All time fav. movie.', 0],
#  ['2025-03-30T08:46:02Z',
#   '@MrTryingtobehappy',
#   'Scarier than any horror movie',
#   0],
#  ['2025-03-30T08:39:07Z', '@thelastdon6562', 'R.I.P Tony Todd', 1],
#  ['2025-03-30T08:35:00Z', '@moyohicks9223', 'Tony Todd ♥️', 0],
#  ['2025-03-30T08:33:53Z',
#   '@InnocentCakeSlice-hn5tz',
#   'This is 🔥 <br>Can&#39;t wait to watch this!!',
#   2],
#  ['2025-03-30T08:27:01Z', '@Sumitkarsoliya', 'Tony Todd 💔', 0],
#  ['2025-03-30T08:16:10Z',
#   '@TheDarkSoul97',
#   'Nice. Stopped the vid on the announcement date to avoid further spoilers lol',
#   0],
#  ['2025-03-30T07:54:21Z',
#   '@MW2F',
#   'Death doesn&#39;t like to be cheated.<br><br>-Literally Death.',
#   1],
#  ['2025-03-30T07:51:33Z', '@mahardhikaisme', 'Ouch! 😂', 0],
#  ['2025-03-30T07:48:16Z',
#   '@scma9247',
#   'From very beginning of watching FD, I have noticed very detail and simple things, because I am scared truly.',
#   0],
#  ['2025-03-30T07:46:15Z',
#   '@Darealstory777',
#   'Do i have to watch previous parts to watch this??',
#   0],
#  ['2025-03-30T17:41:08Z', '@HoratioSAMPUnd3ad', 'Not necessarily.', 0],
#  ['2025-03-30T07:42:39Z',
#   '@AlexGuadarrama-c1d',
#   'I see why death chose to kill Howard first cuZ he was the joy of the family he would be the one who calms them down and be sure that everything is okay so why not take him out first yk',
#   0],
#  ['2025-03-30T07:38:56Z', '@jassi7491', 'Ocd recipe', 0],
#  ['2025-03-30T07:36:01Z',
#   '@thesystem3494',
#   'This is the real movie, after years.',
#   0],
#  ['2025-03-30T07:35:36Z', '@preethishsi6948', 'Trailer 💥💥💥💥🙏🙏🙏🙏🥵🥵🥵🥵', 1],
#  ['2025-03-30T07:34:17Z',
#   '@zerefdragneel2445',
#   'After such a long it death arrives, definitely going to watch in cinemas',
#   0],
#  ['2025-03-30T07:31:38Z',
#   '@PrateekSachdeva',
#   'I really dont think i can do this one! i will never live in peace!',
#   0],
#  ['2025-03-30T07:28:41Z', '@karthikkannan4797', '😢😢😢 its coming ...', 0],
#  ['2025-03-30T07:22:13Z', '@JAMESBOND-mx1eb', 'Childhood trauma is back 💀', 0],
#  ['2025-03-30T07:16:57Z', '@divi2008', 'Waiting from India', 0],
#  ['2025-03-30T07:13:59Z',
#   '@KomodoLand',
#   'I remember the first part when watching on vcd',
#   0],
#  ['2025-03-30T07:13:39Z',
#   '@sfhannn',
#   'Once again to haunt entire generation, now Gen Z!!!!',
#   2],
#  ['2025-03-30T07:13:08Z',
#   '@larserik8899',
#   'The movie series my grandma thinks she lives in',
#   0],
#  ['2025-03-30T07:12:42Z', '@souravmondal0046', 'Coming Hindi dubbed g🎉', 0],
#  ['2025-03-30T07:04:14Z', '@chanuj217', 'The real fear is here😭😭', 0],
#  ['2025-03-30T06:47:10Z', '@smirkorlean', 'I&#39;ve seen enough thanks', 0],
#  ['2025-03-30T06:43:42Z',
#   '@IntSpaceF',
#   'So...grandma causes a never ending generational curse by playing around with death...and her plan is to continue the curse by giving her grandkids a heads-up on their inevitable incoming death because of what she did years ago by avoiding death...thus continuing the curse forever until a generation further down the line decides to accept their fate and give themselves to death in order to finally break the curse?',
#   0],
#  ['2025-03-30T06:42:14Z',
#   '@shojo8708',
#   'Final Destination taught me to never drive behind a logger truck',
#   0],
#  ['2025-03-30T06:42:04Z', '@linfaq', 'TONY TODD 🎉🎉🎉🎉', 0],
#  ['2025-03-30T06:41:41Z',
#   '@billyhutabarat744',
#   'first 20 seconds already give me shiver',
#   0],
#  ['2025-03-30T06:28:06Z',
#   '@KARTHIKA-z2m',
#   'This series is set to traumatize another generation.',
#   0],
#  ['2025-03-30T06:24:01Z',
#   '@czacaesar',
#   'I see what you did there, Mr Magical Ne',
#   0],
#  ['2025-03-30T06:16:45Z',
#   '@BLACKAAROW',
#   'So now we need to fear glass bridges lmao',
#   0],
#  ['2025-03-30T06:12:33Z',
#   '@redromero986',
#   'A lot of homage to the previous films were done. That last cut was almost same as the first movie where the girl was hit by a bus. The lady in the rotating door, was pulled by some kind of a hook, same as the 2nd movie who was unalived because of &quot;man with hooks&quot;. Lawn mower also caused one of the deaths in the 4th film.',
#   0],
#  ['2025-03-30T06:09:34Z',
#   '@Donishaisrael12',
#   'Why is Candyman so little?😢',
#   0],
#  ['2025-03-30T06:02:25Z',
#   '@briansherrod1916',
#   'Great! Now I’m going to be scared all over again lol',
#   1],
#  ['2025-03-30T05:55:03Z',
#   '@immabigfan6036',
#   'The last Time I watch all the final destination movies in one night all by myself is very traumatizing, and I survived. I still want to watch more of this... with someone else, when&#39;s the release?',
#   0],
#  ['2025-03-30T05:54:59Z', '@taty2529', 'omg i cant wait to watch this ☺', 0],
#  ['2025-03-30T05:53:52Z',
#   '@MassachusettsVideos',
#   'I know this Candyman is Final Destination The Devil List aka Final Destination 7 The Devil List (2029) or Final Destination 7 (2029) or Final Destination Apophis (2029) or Final Destination 7 Apophis (2029) and Final Destination: The Book of Death 2032) and Final Destination: New Life (2035) and Final Destination X (2038)...',
#   0],
#  ['2025-03-30T05:48:45Z', '@ameliacamara5414', 'TONY TODD OMGGGG', 0],
#  ['2025-03-30T05:40:55Z',
#   '@sheniemoore4603',
#   'Nostalgia at its finest. I haven’t been to the movies in years but I must go. I have every DVD in the series and it brings back so many memories.',
#   1],
#  ['2025-03-30T05:32:28Z',
#   '@Anneniy',
#   'We&#39;re so ready to be traumatized',
#   0],
#  ['2025-03-30T05:24:32Z',
#   '@mannuanimesh5521',
#   'If you&#39;re careless,you will pay a lot😅',
#   0],
#  ['2025-03-30T05:04:23Z', '@OndrejPohlodko-k9i', '❤❤❤ the best in 2025 🔥', 0],
#  ['2025-03-30T04:59:58Z',
#   '@TkDatNinja',
#   'Tony Todd&#39;s voice gave me insane chills. So glad he was able to finish the movie. Rest in Power Candyman ❤',
#   255],
#  ['2025-03-30T04:33:33Z',
#   '@Spacepizzagaming',
#   'Ain’t no way this bro died <a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=133">2:13</a>',
#   0],
#  ['2025-03-30T04:33:14Z',
#   '@falldruid5540',
#   '<a href="https://www.youtube.com/watch?v=UWMzKXsY9A4&amp;t=49">0:49</a> when the music play i just remember of danganrompa execution theme 😱',
#   1],
#  ['2025-03-30T04:25:30Z',
#   '@arifzain6844',
#   'Warner bros finally thought of killing some people for some unweird reason again',
#   1],
#  ['2025-03-30T04:12:07Z',
#   '@Aden-uc3qp',
#   'Oh yes I can’t wait to get traumatized again',
#   0],
#  ['2025-03-30T04:08:46Z',
#   '@GarageRCR',
#   'Lame.  Make a good original movie please',
#   0],
#  ['2025-03-30T03:53:31Z',
#   '@YeseniaValdivia-ek9pv',
#   'Make sure you check your iced drinks for glass pieces before drinking it',
#   0],
#  ['2025-03-30T03:47:05Z', '@bringtotheheaven9082', 'this is terrifying', 1],
#  ['2025-03-30T03:44:14Z',
#   '@juiuice',
#   'I cannot take this movie seriously if the deaths are so ridiculously over the top',
#   3],
#  ['2025-03-30T03:29:35Z', '@thatboyflip2', 'R.I.P Tony Todd ❤❤❤', 1],
#  ['2025-03-30T03:29:26Z', '@JXWX21', 'I&#39;m only watching for Tony Todd', 0],
#  ['2025-03-30T03:25:03Z',
#   '@oceman5446',
#   'Final Destination - Jump the Shark',
#   0],
#  ['2025-03-30T03:22:27Z',
#   '@slimboslice6587',
#   'Yeeeeeesssssss!!!! 💪🏾💪🏾💪🏾 This, saw and Friday the 13th are my fav franchises',
#   0],
#  ['2025-03-30T03:21:13Z',
#   '@traptgenres9751',
#   'Well no bbq for me this summer backyard giant jenga or ice',
#   1],
#  ['2025-03-30T04:27:22Z', '@dagg310', 'and no beer', 0],
#  ['2025-03-30T03:17:38Z',
#   '@Michael-i7v',
#   'Good old memories coming back from the first part of final destination 😅',
#   1],
#  ['2025-03-30T03:17:27Z',
#   '@Sanidad29876',
#   'This do not look movie horror!!😨😰',
#   1],
#  ['2025-03-30T03:10:51Z',
#   '@donatobytyqi4871',
#   'It’s Final Destination fault that i actually really fear roller coasters, and yet i do consider it one of the greatest franchises of horror movies we have ❤️🥹',
#   1],
#  ['2025-03-30T03:08:15Z', '@Dancefmlivecom', 'at last a new story', 1],
#  ['2025-03-30T03:04:51Z', '@djsulehri.4205', 'Same fear', 0],
#  ['2025-03-30T02:58:37Z',
#   '@Kinkedup',
#   'Get ready to have new fears unlocked 🔓😁',
#   0],
#  ['2025-03-30T02:58:37Z',
#   '@iamzad',
#   'We got another crashed by car death in Final Destination before GTA 6',
#   0],
#  ['2025-03-30T02:47:55Z',
#   '@Matthew-us4ke',
#   '😢 This could be very scary 🫣 😱 and shocking 😳, the massive abrasive and dangerous accidents that people have to be responsible of removing broken glass, water 💦 hose leaving running, forgot to turn off gas cookers at home 🏠, tools 🧰 ⚒️ 🛠️ that can need to be put away right away, air compressor that leaves it unintelligible inflating 🛞, in real life…. The reason why people get into car 🚙 crashes and other vehicle accidents that people died, flammable ⛽️ pouring a lot, terrorizim and crime of bad guys 😈 and bad people who are criminals like violent crimes for murdering people, and anything that can cause mass accidents 😔😔😔😔😔😞😢. BEING CAREFUL FOR cleaning things 🆙!',
#   0],
#  ['2025-03-30T02:43:41Z',
#   '@Imdakotazzz',
#   'the same day as The Weeknd’s movie!!',
#   0],
#  ['2025-03-30T02:38:18Z',
#   '@stufffisuway777',
#   'Im not even gonna try to gatekeep this franchise anymore im so glad more people like it now 😼😼😼',
#   0],
#  ['2025-03-30T02:37:17Z',
#   '@BaseArchieEspio',
#   'Bro this movie comes a day after my birthday what is this😭',
#   0],
#  ['2025-03-30T02:32:49Z',
#   '@toasterowens8916',
#   'These movies just have a such a specifc vibe about them that i saw this out of context as a yotube ad and knew it had to he final destination 20 seconds in.',
#   0],
#  ['2025-03-30T02:30:45Z',
#   '@Fiery_Latina_Goatchan_GF_681',
#   'Very stupiiid movie series',
#   1],
#  ['2025-03-30T02:30:13Z',
#   '@ultimate-x',
#   'I did not expect Tony Todd to show up at all. I’m so happy he’s in this movie. Was this even known info before? I had no idea until this trailer holy shii',
#   0],
#  ['2025-03-30T17:42:31Z',
#   '@HoratioSAMPUnd3ad',
#   'It was, also it was his last movie before he passed away.',
#   0],
#  ['2025-03-30T02:21:29Z', '@TruxtonRios', 'Death is back baby', 1],
#  ['2025-03-30T02:20:10Z',
#   '@pennychoi8108',
#   'I can’t get enough of this trailer, keep looping.',
#   0],
#  ['2025-03-30T02:10:50Z',
#   '@longliveindia837',
#   'Every Soul shall Taste Death source Quraan',
#   0],
#  ['2025-03-30T02:06:28Z',
#   '@fubarexress6359',
#   'I haven&#39;t left my house since the last one. How have things been?',
#   1],
#  ['2025-03-30T02:05:40Z', '@tyronefox3528', 'The imagination is wild 😂', 0],
#  ['2025-03-30T01:55:36Z',
#   '@Blumoon_vii',
#   'I still avoid driving behind a truck that has pipes on it',
#   2],
#  ...]

# %%
df = pd.DataFrame(comments, columns=['PublishedAt', 'Account', 'Comment', 'LikeCount'])
df.head()
# Out:
#             PublishedAt                Account  \
# 0  2025-04-05T06:55:04Z     @nicolas.marsicano
# 1  2025-04-05T06:07:22Z            @bonnnielin
# 2  2025-04-05T05:32:27Z           @BabaDongeng
# 3  2025-04-05T05:02:23Z  @TheAdministratorSCPF
# 4  2025-04-05T04:23:44Z      @sanketgavade8244
#
#                                              Comment  LikeCount
# 0  So as the grandma saved a lot of lives decades...          0
# 1  oh how i’ve been craving for a new final desti...          0
# 2  After saw FD1, i always carrefoul drive behind...          0
# 3  I don’t care how expensive ice is if glass sha...          0
# 4  This movie make me overthink about every second..          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14844 entries, 0 to 14843
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PublishedAt  14844 non-null  object
#  1   Account      14844 non-null  object
#  2   Comment      14844 non-null  object
#  3   LikeCount    14844 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 464.0+ KB

# %%
df.count()
# Out:
# PublishedAt    14844
# Account        14844
# Comment        14844
# LikeCount      14844
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# PublishedAt    0
# Account        0
# Comment        0
# LikeCount      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14843 entries, 0 to 14843
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PublishedAt  14843 non-null  object
#  1   Account      14843 non-null  object
#  2   Comment      14843 non-null  object
#  3   LikeCount    14843 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 579.8+ KB

# %%
df.to_csv('Trailer-Final-Destination-Bloodlines.csv', index=False)
